# %%
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
gdf = gpd.read_parquet('/gpfs/data1/vclgp/xiongl/MatheusWork/result/gedi_amazon.parquet')

# %%
gdf.head()
# Out:
#                     rh_098  lon_lowestmode  lat_lowestmode  \
# h3_12
# 8c8a0cb64996bff  22.580000      -65.126661       -6.676386
# 8c8a0cb64d629ff  25.559999      -65.125328       -6.675954
# 8c8a0cb64d631ff  31.480000      -65.125630       -6.675534
# 8c8a0cb648aebff  19.820000      -65.128770       -6.673458
# 8c8a0cb64c035ff  17.270000      -65.122312       -6.673069
#
#                         shot_number  quality_flag                    geometry
# h3_12
# 8c8a0cb64996bff  111730300400242382          True  POINT (-65.12666 -6.67639)
# 8c8a0cb64d629ff   57131100400242443          True  POINT (-65.12533 -6.67595)
# 8c8a0cb64d631ff   57131100400242442          True  POINT (-65.12563 -6.67553)
# 8c8a0cb648aebff  111730300400242375          True  POINT (-65.12877 -6.67346)
# 8c8a0cb64c035ff  111730200400247690          True  POINT (-65.12231 -6.67307)

# %%
df1= gpd.read_parquet('/gpfs/data1/vclgp/xiongl/MatheusWork/result/agg_2019.parquet')
df2= gpd.read_parquet('/gpfs/data1/vclgp/xiongl/MatheusWork/result/agg_2022.parquet')

# %%
df1.head()
# Out:
#                  rh_098_mean  rh_098_std  \
# h3_11
# 8b8a0a00130cfff    23.860001         NaN
# 8b8a0a00132dfff    30.340000         NaN
# 8b8a0a001a0bfff    25.770000         NaN
# 8b8a0a001a0dfff    34.950001         NaN
# 8b8a0a001a29fff    30.080000         NaN
#
#                                                           geometry
# h3_11
# 8b8a0a00130cfff  POLYGON ((-63.59971 -4.87948, -63.59985 -4.879...
# 8b8a0a00132dfff  POLYGON ((-63.60051 -4.88032, -63.60064 -4.880...
# 8b8a0a001a0bfff  POLYGON ((-63.60253 -4.88312, -63.60267 -4.883...
# 8b8a0a001a0dfff  POLYGON ((-63.60294 -4.88377, -63.60308 -4.883...
# 8b8a0a001a29fff  POLYGON ((-63.60335 -4.88442, -63.60349 -4.884...

# %%
# Merge dataframes based on column indices
import pandas as pd
result = pd.merge(df1, df2, left_index=True, right_index=True)
len(result)
# Out:
# 116339

# %%
result['growth'] = result['rh_098_mean_y'] - result['rh_098_mean_x']
result['percent'] =  result['growth']/ result['rh_098_mean_x'] * 100
result['decrease_flag_50'] = result['percent'] < -50
die = result[result['percent'] < -50]

# %%
result['growth'].hist(bins=100)
result['rh_098_mean_x'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
# decrease > 50%
len(die)
# Out:
# 2755

# %%
len(die[die['growth'] > -30])
# Out:
# 2310

# %%
die.to_parquet('die.parquet')
die[die['growth'] > -30].to_parquet('die_filter.parquet')

# %%
die['growth'].hist(bins=100)
die[die['growth'] > -30]['growth'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
die.head(1)
# Out:
#                  rh_098_mean_x  rh_098_std_x  \
# h3_11
# 8b8a0a2cd2c3fff          34.16           NaN
#
#                                                         geometry_x  \
# h3_11
# 8b8a0a2cd2c3fff  POLYGON ((-63.86889 -4.35368, -63.86903 -4.353...
#
#                  rh_098_mean_y  rh_098_std_y  \
# h3_11
# 8b8a0a2cd2c3fff          11.63           NaN
#
#                                                         geometry_y     growth  \
# h3_11
# 8b8a0a2cd2c3fff  POLYGON ((-63.86889 -4.35368, -63.86903 -4.353... -22.529999
#
#                   percent  decrease_flag_50
# h3_11
# 8b8a0a2cd2c3fff -65.95433              True

# %%
gdf.head(1)
import h3pandas
gdfh3 = gdf.h3.geo_to_h3(11)
gdfh3.head()
# Out:
#                            h3_12     rh_098  lon_lowestmode  lat_lowestmode  \
# h3_11
# 8b8a0cb64996fff  8c8a0cb64996bff  22.580000      -65.126661       -6.676386
# 8b8a0cb64d62fff  8c8a0cb64d629ff  25.559999      -65.125328       -6.675954
# 8b8a0cb64d63fff  8c8a0cb64d631ff  31.480000      -65.125630       -6.675534
# 8b8a0cb648aefff  8c8a0cb648aebff  19.820000      -65.128770       -6.673458
# 8b8a0cb64c03fff  8c8a0cb64c035ff  17.270000      -65.122312       -6.673069
#
#                         shot_number  quality_flag                    geometry
# h3_11
# 8b8a0cb64996fff  111730300400242382          True  POINT (-65.12666 -6.67639)
# 8b8a0cb64d62fff   57131100400242443          True  POINT (-65.12533 -6.67595)
# 8b8a0cb64d63fff   57131100400242442          True  POINT (-65.12563 -6.67553)
# 8b8a0cb648aefff  111730300400242375          True  POINT (-65.12877 -6.67346)
# 8b8a0cb64c03fff  111730200400247690          True  POINT (-65.12231 -6.67307)

# %%
import subprocess
for index, row in die.iterrows():
    hex_ = row['geometry_x']
    idx = gdfh3.sindex.query(hex_)
    shots_in = gdfh3.iloc[idx]
    for s_index, s_row in shots_in.iterrows():
            #print(s_index)
            # Constructing the command as a string
            command = f"shotnumber2wave.py {s_row['shot_number']} figs {s_index}"
            print(command)
            # Running the command using the !python shell command
            # !python {command}
# Out:
# shotnumber2wave.py 213000800400239844 figs 8c8a0a2cd2c3dff
# ## read l1b and l2a files list...
# ## beam number:  BEAM1000
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2022/259/GEDI01_B_2022259075630_O21300_04_T03234_02_005_02_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2022/259/GEDI02_A_2022259075630_O21300_04_T03234_02_003_02_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
# shotnumber2wave.py 19040800100065759 figs 8c8a0a2cd2c33ff
# ## read l1b and l2a files list...
# ## beam number:  BEAM1000
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/104/GEDI01_B_2019104112219_O01904_01_T02079_02_005_02_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/104/GEDI02_A_2019104112219_O01904_01_T02079_02_003_01_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
# shotnumber2wave.py 33320500400237196 figs 8c8a0a448ccc9ff
# ## read l1b and l2a files list...
# ## beam number:  BEAM0101
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/196/GEDI01_B_2019196102848_O03332_04_T03387_02_005_01_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/196/GEDI02_A_2019196102848_O03332_04_T03387_02_003_01_V002_10algs.h5
# ## read l1b and l2a files list...
# ## beam number:  BEAM0101
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/219/GEDI01_B_2019219133724_O03691_01_T01268_02_005_02_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/219/GEDI02_A_2019219133724_O03691_01_T01268_02_003_02_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
# shotnumber2wave.py 212011100100063659 figs 8c8a0ad524955ff
# ## read l1b and l2a files list...
# ## beam number:  BEAM1011
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2022/252/GEDI01_B_2022252224609_O21201_01_T01268_02_005_02_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2022/252/GEDI02_A_2022252224609_O21201_01_T01268_02_003_02_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
# shotnumber2wave.py 36911100100063514 figs 8c8a0ad524953ff
# ## read l1b and l2a files list...
# ## beam number:  BEAM1011
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/219/GEDI01_B_2019219133724_O03691_01_T01268_02_005_02_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/219/GEDI02_A_2019219133724_O03691_01_T01268_02_003_02_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
# shotnumber2wave.py 47211100400233351 figs 8c8a0ad6b8425ff
# ## read l1b and l2a files list...
# ## beam number:  BEAM1011
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/285/GEDI01_B_2019285230159_O04721_04_T00235_02_005_01_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/285/GEDI02_A_2019285230159_O04721_04_T00235_02_003_01_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
# shotnumber2wave.py 207890600100248072 figs 8c8a0ad6b8427ff
# ## read l1b and l2a files list...
# ## beam number:  BEAM0110
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2022/226/GEDI01_B_2022226091748_O20789_01_T02691_02_005_02_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2022/226/GEDI02_A_2022226091748_O20789_01_T02691_02_003_02_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
# shotnumber2wave.py 84660600100246313 figs 8c8a0ad6b8427ff
# ## read l1b and l2a files list...
# ## beam number:  BEAM0110
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2020/162/GEDI01_B_2020162114536_O08466_01_T02691_02_005_01_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2020/162/GEDI02_A_2020162114536_O08466_01_T02691_02_003_01_V002_10algs.h5
# ## plotting...
# ^C
# Traceback (most recent call last):
#   File "/gpfs/data1/vclgp/xiongl/MatheusWork/Mortality4Matheus/shotnumber2wave.py", line 177, in <module>
#     plot_wave(f_final_l1b, f_final_l2a, beam_id, shot_number, output,h3_index)
#   File "/gpfs/data1/vclgp/xiongl/MatheusWork/Mortality4Matheus/shotnumber2wave.py", line 81, in plot_wave
#     plt.figure(figsize=(6, 6))  # Adjust the figure size as needed
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/matplotlib/pyplot.py", line 808, in figure
#     manager = new_figure_manager(
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/matplotlib/pyplot.py", line 326, in new_figure_manager
#     _warn_if_gui_out_of_main_thread()
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/matplotlib/pyplot.py", line 316, in _warn_if_gui_out_of_main_thread
#     if (_get_required_interactive_framework(_get_backend_mod())
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/matplotlib/pyplot.py", line 217, in _get_backend_mod
#     switch_backend(dict.__getitem__(rcParams, "backend"))
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/matplotlib/pyplot.py", line 288, in switch_backend
#     class backend_mod(matplotlib.backend_bases._Backend):
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/matplotlib/pyplot.py", line 289, in backend_mod
#     locals().update(vars(importlib.import_module(backend_name)))
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py", line 15, in <module>
#     from IPython.core.interactiveshell import InteractiveShell
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/IPython/__init__.py", line 53, in <module>
#     from .terminal.embed import embed
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/IPython/terminal/embed.py", line 14, in <module>
#     from IPython.core.magic import Magics, magics_class, line_magic
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/IPython/core/magic.py", line 20, in <module>
#     from . import oinspect
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/IPython/core/oinspect.py", line 29, in <module>
#     from IPython.core import page
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/IPython/core/page.py", line 28, in <module>
#     from IPython.display import display
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/IPython/display.py", line 16, in <module>
# shotnumber2wave.py 191870600100251479 figs 8c8a0b4090dadff
# ## read l1b and l2a files list...
# ^C
# Traceback (most recent call last):
#   File "/gpfs/data1/vclgp/xiongl/MatheusWork/Mortality4Matheus/shotnumber2wave.py", line 136, in <module>
#     l1b_list = glob.glob(datapath + "GEDI01_B*.h5")
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 24, in glob
#     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 86, in _iglob
#     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly):
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 94, in _glob1
#     names = _listdir(dirname, dir_fd, dironly)
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 164, in _listdir
#     return list(it)
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 149, in _iterdir
#     if not dironly or entry.is_dir():
# KeyboardInterrupt
# shotnumber2wave.py 38590600100250847 figs 8c8a0b4090da3ff
# ## read l1b and l2a files list...
# ## beam number:  BEAM0110
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/230/GEDI01_B_2019230092613_O03859_01_T00350_02_005_01_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/230/GEDI02_A_2019230092613_O03859_01_T00350_02_003_01_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
# shotnumber2wave.py 191870500100065259 figs 8c8a0b409b40dff
# ## read l1b and l2a files list...
# ^C
# Traceback (most recent call last):
#   File "/gpfs/data1/vclgp/xiongl/MatheusWork/Mortality4Matheus/shotnumber2wave.py", line 136, in <module>
#     l1b_list = glob.glob(datapath + "GEDI01_B*.h5")
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 24, in glob
#     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 86, in _iglob
#     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly):
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 94, in _glob1
#     names = _listdir(dirname, dir_fd, dironly)
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 164, in _listdir
#     return list(it)
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 149, in _iterdir
#     if not dironly or entry.is_dir():
# KeyboardInterrupt
# shotnumber2wave.py 38590500100064820 figs 8c8a0b409b403ff
# Exception ignored in: <function _releaseLock at 0x2adb8771f400>
# Traceback (most recent call last):
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/logging/__init__.py", line 228, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# IOStream.flush timed out
# ## read l1b and l2a files list...
# ^C
# Traceback (most recent call last):
#   File "/gpfs/data1/vclgp/xiongl/MatheusWork/Mortality4Matheus/shotnumber2wave.py", line 136, in <module>
#     l1b_list = glob.glob(datapath + "GEDI01_B*.h5")
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 24, in glob
#     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 86, in _iglob
#     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly):
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 94, in _glob1
#     names = _listdir(dirname, dir_fd, dironly)
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 164, in _listdir
#     return list(it)
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/glob.py", line 149, in _iterdir
#     if not dironly or entry.is_dir():
# KeyboardInterrupt
# shotnumber2wave.py 191870800100066387 figs 8c8a0b40ba1cdff
# ^C
# Traceback (most recent call last):
#   File "/gpfs/data1/vclgp/xiongl/MatheusWork/Mortality4Matheus/shotnumber2wave.py", line 5, in <module>
#     import h3
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/h3/__init__.py", line 3, in <module>
#     from .api.basic_str import *
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/h3/api/__init__.py", line 3, in <module>
#     from . import basic_int
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/h3/api/basic_int/__init__.py", line 1, in <module>
#     from ._public_api import *  # noqa
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/h3/api/basic_int/_public_api.py", line 9, in <module>
#     from ._binding import _binding
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/h3/api/basic_int/_binding.py", line 16, in <module>
#     from ... import _cy
#   File "/gpfs/data1/vclgp/decontot/environments/gedih3/lib/python3.10/site-packages/h3/_cy/__init__.py", line 16, in <module>
#     from .cells import (
#   File "cells.pyx", line 1, in init h3._cy.cells
#   File "<frozen importlib._bootstrap>", line 404, in parent
# KeyboardInterrupt
# shotnumber2wave.py 38590800100066141 figs 8c8a0b40ba1cbff
# KeyboardInterrupt

# %%
gdf.iloc[idx]
# to do 
# give a hexgon : e.g. 8b8a0a2cd2c3fff 
# return nearby shots number 
# return each gedi waveform
# Out:
#                  rh_098  lon_lowestmode  lat_lowestmode         shot_number  \
# h3_12
# 8c8a0a448ccc9ff   27.91      -63.341348       -4.718846   33320500400237196
# 8c8a0a448ccc9ff   12.88      -63.341296       -4.718810  226200600100248962
#
#                  quality_flag                    geometry
# h3_12
# 8c8a0a448ccc9ff          True  POINT (-63.34135 -4.71885)
# 8c8a0a448ccc9ff          True  POINT (-63.34130 -4.71881)

# %%
# python shotnumber2wave.py <shot_number> <output_dir>
# %run shotnumber2wave.py 213000800400239844 figs 8c8a0a448ccc9ff
# Out:
# ## read l1b and l2a files list...
# ## beam number:  BEAM0101
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/196/GEDI01_B_2019196102848_O03332_04_T03387_02_005_01_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2019/196/GEDI02_A_2019196102848_O03332_04_T03387_02_003_01_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...

# %%
# %run shotnumber2wave.py 226200600100248962 figs 8c8a0a448ccc9ff
# Out:
# ## read l1b and l2a files list...
# ## beam number:  BEAM0110
# ## find l1b file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2022/344/GEDI01_B_2022344103356_O22620_01_T11076_02_005_02_V002.h5
# ## find l2a file:  /gpfs/data1/vclgp/data/iss_gedi/soc/2022/344/GEDI02_A_2022344103356_O22620_01_T11076_02_003_02_V002_10algs.h5
# ## plotting...
# ## save plot in jpg...
